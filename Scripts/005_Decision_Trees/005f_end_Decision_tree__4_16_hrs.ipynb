# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import TimeSeriesSplit

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.tree import export_graphviz
from IPython.display import Image 

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier

from sklearn.model_selection import GridSearchCV

from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import plot_roc_curve
from sklearn.inspection import permutation_importance
from sklearn.metrics import roc_auc_score
import shap


import math

# %%
df = pd.read_csv("../../Data/df_standardised_end_test_6hr.csv")
df = df.drop(columns = ["Unnamed: 0","X","X1.hr","X2.hr","X3.hr","X17.hr","X18.hr","X19.hr"
                        ,"X20.hr","X21.hr","X22.hr","X23.hr","X24.hr","X25.hr","X26.hr","X27.hr","X28.hr","chunk"])
df
# Out:
#        abnormal     X4.hr     X5.hr     X6.hr     X7.hr     X8.hr     X9.hr  \
# 0             0 -0.437480  0.710856  1.819656  0.310877 -0.650791 -0.172488
# 1             0 -0.024752 -0.437480  0.710856  1.819656  0.310877 -0.650791
# 2             0 -1.372619 -0.024752 -0.437480  0.710856  1.819656  0.310877
# 3             0 -0.601068 -1.372619 -0.024752 -0.437480  0.710856  1.819656
# 4             0  0.417116 -0.601068 -1.372619 -0.024752 -0.437480  0.710856
# ...         ...       ...       ...       ...       ...       ...       ...
# 31653         0  1.253461  0.491539  0.483600 -0.892592  1.115237  0.551112
# 31654         0  0.514161  1.253461  0.491539  0.483600 -0.892592  1.115237
# 31655         0 -0.053325  0.514161  1.253461  0.491539  0.483600 -0.892592
# 31656         0 -0.091542 -0.053325  0.514161  1.253461  0.491539  0.483600
# 31657         0  0.573887 -0.091542 -0.053325  0.514161  1.253461  0.491539
#
#          X10.hr    X11.hr    X12.hr    X13.hr    X14.hr    X15.hr    X16.hr  \
# 0     -1.328283 -0.466315  0.541083  0.114208 -1.192720  1.490788 -0.650791
# 1     -0.172488 -1.328283 -0.466315  0.541083  0.114208 -1.192720  1.490788
# 2     -0.650791 -0.172488 -1.328283 -0.466315  0.541083  0.114208 -1.192720
# 3      0.310877 -0.650791 -0.172488 -1.328283 -0.466315  0.541083  0.114208
# 4      1.819656  0.310877 -0.650791 -0.172488 -1.328283 -0.466315  0.541083
# ...         ...       ...       ...       ...       ...       ...       ...
# 31653  1.321054  1.428236  1.249428  0.862519  1.803022  1.280856  1.984037
# 31654  0.551112  1.321054  1.428236  1.249428  0.862519  1.803022  1.280856
# 31655  1.115237  0.551112  1.321054  1.428236  1.249428  0.862519  1.803022
# 31656 -0.892592  1.115237  0.551112  1.321054  1.428236  1.249428  0.862519
# 31657  0.483600 -0.892592  1.115237  0.551112  1.321054  1.428236  1.249428
#
#       train_test
# 0          train
# 1          train
# 2          train
# 3          train
# 4          train
# ...          ...
# 31653       test
# 31654       test
# 31655       test
# 31656       test
# 31657       test
#
# [31658 rows x 15 columns]

# %%
train = df.loc[df['train_test'] == "train"]
test = df.loc[df['train_test'] == "test"]

# %%
y_train = train.pop("abnormal")
X_train = train
X_train = X_train.drop(columns = ["train_test"])
y_test = test.pop("abnormal")
X_test = test
X_test = X_test.drop(columns = ["train_test"])

# %%
def get_results(truth, prediction, df, idx):
    

    acc = accuracy_score(truth, prediction)
    f1 = f1_score(truth, prediction)
    precision = precision_score(truth, prediction)
    recall = recall_score(truth, prediction)

    df.loc[idx,:] = [acc, f1, precision, recall]

    return df

# %%
results = pd.DataFrame(index = ['Decision Tree'], 
                       columns = ['accuracy', 'f1', 'precision', 'recall'])

# %%
clf = DecisionTreeClassifier(max_depth = 3, random_state = 13)
clf.fit(X=X_train,y=y_train)

y_pred = clf.predict(X_test)

results = get_results(y_test, y_pred, results, 'Decision Tree')


fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(clf, 
                   feature_names=X_train.columns,  
                   class_names=['normal', 'abnormal'],
                   filled=True,  proportion = True)

# %%
labels = [1, 0]
cm = confusion_matrix(y_test, y_pred, labels=labels)
ax= plt.subplot()
sns.heatmap(cm, annot=True, ax = ax, fmt = 'g')

ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels');
ax.set_title('Confusion Matrix');
ax.xaxis.set_ticklabels(['abnormal', 'normal']); 
ax.yaxis.set_ticklabels(['abnormal', 'normal'])

plt.show()

# %%
results
# Out:
#                accuracy         f1 precision     recall
# Decision Tree  0.986985  0.0392157       0.5  0.0204082

# %%
for i in range(100):
    clf = DecisionTreeClassifier(max_depth = 3, class_weight={0:1, 1:i}, random_state = 13)
    clf.fit(X=X_train,y=y_train)

    y_pred = clf.predict(X_test)

    results = get_results(y_test, y_pred, results, i)


    #fig = plt.figure(figsize=(25,20))
    #_ = tree.plot_tree(clf, 
                   #feature_names=X_train.columns,  
                   #class_names=['normal', 'abnormal'],
                   #filled=True,  proportion = True)
# Out:
# Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.

# %%
results.sort_values('f1', ascending=False)
# Out:
#                accuracy         f1  precision     recall
# 6              0.978486   0.372093        0.3   0.489796
# 5              0.981939   0.358491   0.333333   0.387755
# 7              0.973971   0.355263   0.262136    0.55102
# 8              0.973971   0.355263   0.262136    0.55102
# 9              0.973971   0.355263   0.262136    0.55102
# ...                 ...        ...        ...        ...
# 80             0.749535  0.0871249  0.0457317   0.918367
# 79             0.749535  0.0871249  0.0457317   0.918367
# 1              0.986985  0.0392157        0.5  0.0204082
# Decision Tree  0.986985  0.0392157        0.5  0.0204082
# 0              0.986985          0          0          0
#
# [101 rows x 4 columns]

# %%
clf = DecisionTreeClassifier(max_depth = 3, class_weight={0:1, 1:6}, random_state = 13)
clf.fit(X=X_train,y=y_train)

y_pred = clf.predict(X_test)

results = get_results(y_test, y_pred, results, i)


fig = plt.figure(figsize=(24,12))
_ = tree.plot_tree(clf, 
                feature_names=X_train.columns,  
                class_names=['normal', 'abnormal'],
                filled=True,  proportion = True, fontsize=15)

plt.savefig("../../Plots/Decision_tree.pdf")

# %%
labels = [1, 0]
cm = confusion_matrix(y_test, y_pred, labels=labels)
ax= plt.subplot()
sns.heatmap(cm, annot=True, ax = ax, fmt = 'g')

ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels');
ax.set_title('Confusion Matrix');
ax.xaxis.set_ticklabels(['abnormal', 'normal']); 
ax.yaxis.set_ticklabels(['abnormal', 'normal'])

plt.show()

# %%
plot_roc_curve(clf,X_test,y_test)
plt.show()

# %%
y_score = clf.predict_proba(X_test)

# %%
n_bootstraps = 1000
rng_seed = 42  # control reproducibility
bootstrapped_scores = []

y_test = y_test.reset_index()
y_test = y_test.drop(columns = ["index"])
y_test = y_test.squeeze()

y_pred = pd.Series(y_pred)

rng = np.random.RandomState(rng_seed)
for i in range(n_bootstraps):
    # bootstrap by sampling with replacement on the prediction indices
    indices = rng.randint(0, len(y_pred), len(y_pred))
    if len(np.unique(y_test[indices])) < 2:
        # We need at least one positive and one negative sample for ROC AUC
        # to be defined: reject the sample
        continue

    score = roc_auc_score(y_test[indices], y_score[indices, 1])
    bootstrapped_scores.append(score)
    print("Bootstrap #{} ROC area: {:0.3f}".format(i + 1, score))


sorted_scores = np.array(bootstrapped_scores)
sorted_scores.sort()

# Computing the lower and upper bound of the 90% confidence interval
# You can change the bounds percentiles to 0.025 and 0.975 to get
# a 95% confidence interval instead.
confidence_lower = sorted_scores[int(0.05 * len(sorted_scores))]
confidence_upper = sorted_scores[int(0.95 * len(sorted_scores))]
print("Confidence interval for the score: [{:0.3f} - {:0.3}]".format(
    confidence_lower, confidence_upper))
# Out:
# Bootstrap #1 ROC area: 0.834
# Bootstrap #2 ROC area: 0.878
# Bootstrap #3 ROC area: 0.906
# Bootstrap #4 ROC area: 0.913
# Bootstrap #5 ROC area: 0.892
# Bootstrap #6 ROC area: 0.847
# Bootstrap #7 ROC area: 0.865
# Bootstrap #8 ROC area: 0.910
# Bootstrap #9 ROC area: 0.874
# Bootstrap #10 ROC area: 0.883
# Bootstrap #11 ROC area: 0.883
# Bootstrap #12 ROC area: 0.817
# Bootstrap #13 ROC area: 0.892
# Bootstrap #14 ROC area: 0.938
# Bootstrap #15 ROC area: 0.874
# Bootstrap #16 ROC area: 0.870
# Bootstrap #17 ROC area: 0.873
# Bootstrap #18 ROC area: 0.827
# Bootstrap #19 ROC area: 0.881
# Bootstrap #20 ROC area: 0.845
# Bootstrap #21 ROC area: 0.899
# Bootstrap #22 ROC area: 0.901
# Bootstrap #23 ROC area: 0.856
# Bootstrap #24 ROC area: 0.933
# Bootstrap #25 ROC area: 0.892
# Bootstrap #26 ROC area: 0.895
# Bootstrap #27 ROC area: 0.858
# Bootstrap #28 ROC area: 0.863
# Bootstrap #29 ROC area: 0.898
# Bootstrap #30 ROC area: 0.784
# Bootstrap #31 ROC area: 0.925
# Bootstrap #32 ROC area: 0.876
# Bootstrap #33 ROC area: 0.876
# Bootstrap #34 ROC area: 0.905
# Bootstrap #35 ROC area: 0.943
# Bootstrap #36 ROC area: 0.843
# Bootstrap #37 ROC area: 0.892
# Bootstrap #38 ROC area: 0.945
# Bootstrap #39 ROC area: 0.882
# Bootstrap #40 ROC area: 0.925
# Bootstrap #41 ROC area: 0.893
# Bootstrap #42 ROC area: 0.920
# Bootstrap #43 ROC area: 0.874
# Bootstrap #44 ROC area: 0.920
# Bootstrap #45 ROC area: 0.848
# Bootstrap #46 ROC area: 0.929
# Bootstrap #47 ROC area: 0.904
# Bootstrap #48 ROC area: 0.875
# Bootstrap #49 ROC area: 0.895
# Bootstrap #50 ROC area: 0.880
# Bootstrap #51 ROC area: 0.866
# Bootstrap #52 ROC area: 0.878
# Bootstrap #53 ROC area: 0.878
# Bootstrap #54 ROC area: 0.908
# Bootstrap #55 ROC area: 0.871
# Bootstrap #56 ROC area: 0.865
# Bootstrap #57 ROC area: 0.890
# Bootstrap #58 ROC area: 0.856
# Bootstrap #59 ROC area: 0.885
# Bootstrap #60 ROC area: 0.888
# Bootstrap #61 ROC area: 0.919
# Bootstrap #62 ROC area: 0.855
# Bootstrap #63 ROC area: 0.887
# Bootstrap #64 ROC area: 0.907
# Bootstrap #65 ROC area: 0.935
# Bootstrap #66 ROC area: 0.932
# Bootstrap #67 ROC area: 0.911
# Bootstrap #68 ROC area: 0.834
# Bootstrap #69 ROC area: 0.890
# Bootstrap #70 ROC area: 0.878
# Bootstrap #71 ROC area: 0.865
# Bootstrap #72 ROC area: 0.884
# Bootstrap #73 ROC area: 0.890
# Bootstrap #74 ROC area: 0.891
# Bootstrap #75 ROC area: 0.898
# Bootstrap #76 ROC area: 0.857
# Bootstrap #77 ROC area: 0.882
# Bootstrap #78 ROC area: 0.928
# Bootstrap #79 ROC area: 0.878
# Bootstrap #80 ROC area: 0.901
# Bootstrap #81 ROC area: 0.900
# Bootstrap #82 ROC area: 0.911
# Bootstrap #83 ROC area: 0.855
# Bootstrap #84 ROC area: 0.906
# Bootstrap #85 ROC area: 0.909
# Bootstrap #86 ROC area: 0.863
# Bootstrap #87 ROC area: 0.888
# Bootstrap #88 ROC area: 0.860
# Bootstrap #89 ROC area: 0.919
# Bootstrap #90 ROC area: 0.894
# Bootstrap #91 ROC area: 0.924
# Bootstrap #92 ROC area: 0.903
# Bootstrap #93 ROC area: 0.856
# Bootstrap #94 ROC area: 0.785
# Bootstrap #95 ROC area: 0.895
# Bootstrap #96 ROC area: 0.917
# Bootstrap #97 ROC area: 0.864
# Bootstrap #98 ROC area: 0.833
# Bootstrap #99 ROC area: 0.892
# Bootstrap #100 ROC area: 0.866
# Bootstrap #101 ROC area: 0.878
# Bootstrap #102 ROC area: 0.867
# Bootstrap #103 ROC area: 0.858
# Bootstrap #104 ROC area: 0.916
# Bootstrap #105 ROC area: 0.888
# Bootstrap #106 ROC area: 0.918
# Bootstrap #107 ROC area: 0.894
# Bootstrap #108 ROC area: 0.874
# Bootstrap #109 ROC area: 0.875
# Bootstrap #110 ROC area: 0.927
# Bootstrap #111 ROC area: 0.920
# Bootstrap #112 ROC area: 0.883
# Bootstrap #113 ROC area: 0.868
# Bootstrap #114 ROC area: 0.909
# Bootstrap #115 ROC area: 0.908
# Bootstrap #116 ROC area: 0.920
# Bootstrap #117 ROC area: 0.907
# Bootstrap #118 ROC area: 0.892
# Bootstrap #119 ROC area: 0.860
# Bootstrap #120 ROC area: 0.897
# Bootstrap #121 ROC area: 0.885
# Bootstrap #122 ROC area: 0.882
# Bootstrap #123 ROC area: 0.868
# Bootstrap #124 ROC area: 0.898
# Bootstrap #125 ROC area: 0.864
# Bootstrap #126 ROC area: 0.878
# Bootstrap #127 ROC area: 0.869
# Bootstrap #128 ROC area: 0.844
# Bootstrap #129 ROC area: 0.879
# Bootstrap #130 ROC area: 0.861
# Bootstrap #131 ROC area: 0.872
# Bootstrap #132 ROC area: 0.891
# Bootstrap #133 ROC area: 0.898
# Bootstrap #134 ROC area: 0.875
# Bootstrap #135 ROC area: 0.904
# Bootstrap #136 ROC area: 0.876
# Bootstrap #137 ROC area: 0.921
# Bootstrap #138 ROC area: 0.904
# Bootstrap #139 ROC area: 0.903
# Bootstrap #140 ROC area: 0.893
# Bootstrap #141 ROC area: 0.852
# Bootstrap #142 ROC area: 0.931
# Bootstrap #143 ROC area: 0.876
# Bootstrap #144 ROC area: 0.893
# Bootstrap #145 ROC area: 0.917
# Bootstrap #146 ROC area: 0.899
# Bootstrap #147 ROC area: 0.885
# Bootstrap #148 ROC area: 0.892
# Bootstrap #149 ROC area: 0.912
# Bootstrap #150 ROC area: 0.870
# Bootstrap #151 ROC area: 0.897
# Bootstrap #152 ROC area: 0.910
# Bootstrap #153 ROC area: 0.853
# Bootstrap #154 ROC area: 0.893
# Bootstrap #155 ROC area: 0.927
# Bootstrap #156 ROC area: 0.839
# Bootstrap #157 ROC area: 0.862
# Bootstrap #158 ROC area: 0.882
# Bootstrap #159 ROC area: 0.890
# Bootstrap #160 ROC area: 0.907
# Bootstrap #161 ROC area: 0.854
# Bootstrap #162 ROC area: 0.886
# Bootstrap #163 ROC area: 0.942
# Bootstrap #164 ROC area: 0.893
# Bootstrap #165 ROC area: 0.845
# Bootstrap #166 ROC area: 0.894
# Bootstrap #167 ROC area: 0.935
# Bootstrap #168 ROC area: 0.847
# Bootstrap #169 ROC area: 0.898
# Bootstrap #170 ROC area: 0.924
# Bootstrap #171 ROC area: 0.906
# Bootstrap #172 ROC area: 0.882
# Bootstrap #173 ROC area: 0.881
# Bootstrap #174 ROC area: 0.853
# Bootstrap #175 ROC area: 0.823
# Bootstrap #176 ROC area: 0.936
# Bootstrap #177 ROC area: 0.898
# Bootstrap #178 ROC area: 0.914
# Bootstrap #179 ROC area: 0.945
# Bootstrap #180 ROC area: 0.873
# Bootstrap #181 ROC area: 0.896
# Bootstrap #182 ROC area: 0.939
# Bootstrap #183 ROC area: 0.906
# Bootstrap #184 ROC area: 0.869
# Bootstrap #185 ROC area: 0.880
# Bootstrap #186 ROC area: 0.908
# Bootstrap #187 ROC area: 0.892
# Bootstrap #188 ROC area: 0.917
# Bootstrap #189 ROC area: 0.856
# Bootstrap #190 ROC area: 0.929
# Bootstrap #191 ROC area: 0.853
# Bootstrap #192 ROC area: 0.865
# Bootstrap #193 ROC area: 0.890
# Bootstrap #194 ROC area: 0.873
# Bootstrap #195 ROC area: 0.861
# Bootstrap #196 ROC area: 0.900
# Bootstrap #197 ROC area: 0.851
# Bootstrap #198 ROC area: 0.903
# Bootstrap #199 ROC area: 0.844
# Bootstrap #200 ROC area: 0.834
# Bootstrap #201 ROC area: 0.824
# Bootstrap #202 ROC area: 0.883
# Bootstrap #203 ROC area: 0.894
# Bootstrap #204 ROC area: 0.913
# Bootstrap #205 ROC area: 0.863
# Bootstrap #206 ROC area: 0.880
# Bootstrap #207 ROC area: 0.882
# Bootstrap #208 ROC area: 0.918
# Bootstrap #209 ROC area: 0.926
# Bootstrap #210 ROC area: 0.920
# Bootstrap #211 ROC area: 0.932
# Bootstrap #212 ROC area: 0.888
# Bootstrap #213 ROC area: 0.902
# Bootstrap #214 ROC area: 0.896
# Bootstrap #215 ROC area: 0.882
# Bootstrap #216 ROC area: 0.877
# Bootstrap #217 ROC area: 0.918
# Bootstrap #218 ROC area: 0.851
# Bootstrap #219 ROC area: 0.900
# Bootstrap #220 ROC area: 0.928
# Bootstrap #221 ROC area: 0.905
# Bootstrap #222 ROC area: 0.848
# Bootstrap #223 ROC area: 0.896
# Bootstrap #224 ROC area: 0.937
# Bootstrap #225 ROC area: 0.891
# Bootstrap #226 ROC area: 0.859
# Bootstrap #227 ROC area: 0.881
# Bootstrap #228 ROC area: 0.911
# Bootstrap #229 ROC area: 0.862
# Bootstrap #230 ROC area: 0.875
# Bootstrap #231 ROC area: 0.890
# Bootstrap #232 ROC area: 0.902
# Bootstrap #233 ROC area: 0.831
# Bootstrap #234 ROC area: 0.805
# Bootstrap #235 ROC area: 0.951
# Bootstrap #236 ROC area: 0.912
# Bootstrap #237 ROC area: 0.894
# Bootstrap #238 ROC area: 0.929
# Bootstrap #239 ROC area: 0.907
# Bootstrap #240 ROC area: 0.920
# Bootstrap #241 ROC area: 0.905
# Bootstrap #242 ROC area: 0.892
# Bootstrap #243 ROC area: 0.869
# Bootstrap #244 ROC area: 0.866
# Bootstrap #245 ROC area: 0.922
# Bootstrap #246 ROC area: 0.872
# Bootstrap #247 ROC area: 0.874
# Bootstrap #248 ROC area: 0.905
# Bootstrap #249 ROC area: 0.857
# Bootstrap #250 ROC area: 0.864
# Bootstrap #251 ROC area: 0.793
# Bootstrap #252 ROC area: 0.878
# Bootstrap #253 ROC area: 0.866
# Bootstrap #254 ROC area: 0.883
# Bootstrap #255 ROC area: 0.867
# Bootstrap #256 ROC area: 0.892
# Bootstrap #257 ROC area: 0.914
# Bootstrap #258 ROC area: 0.899
# Bootstrap #259 ROC area: 0.925
# Bootstrap #260 ROC area: 0.852
# Bootstrap #261 ROC area: 0.876
# Bootstrap #262 ROC area: 0.931
# Bootstrap #263 ROC area: 0.909
# Bootstrap #264 ROC area: 0.868
# Bootstrap #265 ROC area: 0.892
# Bootstrap #266 ROC area: 0.900
# Bootstrap #267 ROC area: 0.888
# Bootstrap #268 ROC area: 0.905
# Bootstrap #269 ROC area: 0.890
# Bootstrap #270 ROC area: 0.903
# Bootstrap #271 ROC area: 0.873
# Bootstrap #272 ROC area: 0.872
# Bootstrap #273 ROC area: 0.909
# Bootstrap #274 ROC area: 0.920
# Bootstrap #275 ROC area: 0.890
# Bootstrap #276 ROC area: 0.935
# Bootstrap #277 ROC area: 0.849
# Bootstrap #278 ROC area: 0.920
# Bootstrap #279 ROC area: 0.862
# Bootstrap #280 ROC area: 0.873
# Bootstrap #281 ROC area: 0.875
# Bootstrap #282 ROC area: 0.910
# Bootstrap #283 ROC area: 0.898
# Bootstrap #284 ROC area: 0.891
# Bootstrap #285 ROC area: 0.907
# Bootstrap #286 ROC area: 0.891
# Bootstrap #287 ROC area: 0.892
# Bootstrap #288 ROC area: 0.887
# Bootstrap #289 ROC area: 0.858
# Bootstrap #290 ROC area: 0.793
# Bootstrap #291 ROC area: 0.854
# Bootstrap #292 ROC area: 0.888
# Bootstrap #293 ROC area: 0.878
# Bootstrap #294 ROC area: 0.891
# Bootstrap #295 ROC area: 0.889
# Bootstrap #296 ROC area: 0.917
# Bootstrap #297 ROC area: 0.900
# Bootstrap #298 ROC area: 0.933
# Bootstrap #299 ROC area: 0.832
# Bootstrap #300 ROC area: 0.883
# Bootstrap #301 ROC area: 0.906
# Bootstrap #302 ROC area: 0.882
# Bootstrap #303 ROC area: 0.887
# Bootstrap #304 ROC area: 0.896
# Bootstrap #305 ROC area: 0.903
# Bootstrap #306 ROC area: 0.875
# Bootstrap #307 ROC area: 0.906
# Bootstrap #308 ROC area: 0.867
# Bootstrap #309 ROC area: 0.932
# Bootstrap #310 ROC area: 0.880
# Bootstrap #311 ROC area: 0.880
# Bootstrap #312 ROC area: 0.895
# Bootstrap #313 ROC area: 0.891
# Bootstrap #314 ROC area: 0.932
# Bootstrap #315 ROC area: 0.943
# Bootstrap #316 ROC area: 0.871
# Bootstrap #317 ROC area: 0.883
# Bootstrap #318 ROC area: 0.902
# Bootstrap #319 ROC area: 0.851
# Bootstrap #320 ROC area: 0.856
# Bootstrap #321 ROC area: 0.920
# Bootstrap #322 ROC area: 0.911
# Bootstrap #323 ROC area: 0.929
# Bootstrap #324 ROC area: 0.918
# Bootstrap #325 ROC area: 0.884
# Bootstrap #326 ROC area: 0.824
# Bootstrap #327 ROC area: 0.893
# Bootstrap #328 ROC area: 0.880
# Bootstrap #329 ROC area: 0.882
# Bootstrap #330 ROC area: 0.918
# Bootstrap #331 ROC area: 0.851
# Bootstrap #332 ROC area: 0.865
# Bootstrap #333 ROC area: 0.855
# Bootstrap #334 ROC area: 0.861
# Bootstrap #335 ROC area: 0.842
# Bootstrap #336 ROC area: 0.874
# Bootstrap #337 ROC area: 0.907
# Bootstrap #338 ROC area: 0.866
# Bootstrap #339 ROC area: 0.836
# Bootstrap #340 ROC area: 0.890
# Bootstrap #341 ROC area: 0.858
# Bootstrap #342 ROC area: 0.839
# Bootstrap #343 ROC area: 0.870
# Bootstrap #344 ROC area: 0.900
# Bootstrap #345 ROC area: 0.863
# Bootstrap #346 ROC area: 0.890
# Bootstrap #347 ROC area: 0.910
# Bootstrap #348 ROC area: 0.905
# Bootstrap #349 ROC area: 0.869
# Bootstrap #350 ROC area: 0.870
# Bootstrap #351 ROC area: 0.898
# Bootstrap #352 ROC area: 0.916
# Bootstrap #353 ROC area: 0.837
# Bootstrap #354 ROC area: 0.899
# Bootstrap #355 ROC area: 0.848
# Bootstrap #356 ROC area: 0.875
# Bootstrap #357 ROC area: 0.920
# Bootstrap #358 ROC area: 0.889
# Bootstrap #359 ROC area: 0.921
# Bootstrap #360 ROC area: 0.858
# Bootstrap #361 ROC area: 0.911
# Bootstrap #362 ROC area: 0.895
# Bootstrap #363 ROC area: 0.870
# Bootstrap #364 ROC area: 0.889
# Bootstrap #365 ROC area: 0.863
# Bootstrap #366 ROC area: 0.853
# Bootstrap #367 ROC area: 0.887
# Bootstrap #368 ROC area: 0.844
# Bootstrap #369 ROC area: 0.893
# Bootstrap #370 ROC area: 0.915
# Bootstrap #371 ROC area: 0.859
# Bootstrap #372 ROC area: 0.861
# Bootstrap #373 ROC area: 0.896
# Bootstrap #374 ROC area: 0.850
# Bootstrap #375 ROC area: 0.924
# Bootstrap #376 ROC area: 0.881
# Bootstrap #377 ROC area: 0.897
# Bootstrap #378 ROC area: 0.896
# Bootstrap #379 ROC area: 0.895
# Bootstrap #380 ROC area: 0.801
# Bootstrap #381 ROC area: 0.829
# Bootstrap #382 ROC area: 0.918
# Bootstrap #383 ROC area: 0.865
# Bootstrap #384 ROC area: 0.905
# Bootstrap #385 ROC area: 0.868
# Bootstrap #386 ROC area: 0.884
# Bootstrap #387 ROC area: 0.885
# Bootstrap #388 ROC area: 0.899
# Bootstrap #389 ROC area: 0.910
# Bootstrap #390 ROC area: 0.929
# Bootstrap #391 ROC area: 0.852
# Bootstrap #392 ROC area: 0.833
# Bootstrap #393 ROC area: 0.893
# Bootstrap #394 ROC area: 0.905
# Bootstrap #395 ROC area: 0.925
# Bootstrap #396 ROC area: 0.863
# Bootstrap #397 ROC area: 0.874
# Bootstrap #398 ROC area: 0.900
# Bootstrap #399 ROC area: 0.831
# Bootstrap #400 ROC area: 0.881
# Bootstrap #401 ROC area: 0.854
# Bootstrap #402 ROC area: 0.889
# Bootstrap #403 ROC area: 0.885
# Bootstrap #404 ROC area: 0.850
# Bootstrap #405 ROC area: 0.859
# Bootstrap #406 ROC area: 0.894
# Bootstrap #407 ROC area: 0.892
# Bootstrap #408 ROC area: 0.856
# Bootstrap #409 ROC area: 0.885
# Bootstrap #410 ROC area: 0.815
# Bootstrap #411 ROC area: 0.846
# Bootstrap #412 ROC area: 0.912
# Bootstrap #413 ROC area: 0.850
# Bootstrap #414 ROC area: 0.894
# Bootstrap #415 ROC area: 0.872
# Bootstrap #416 ROC area: 0.945
# Bootstrap #417 ROC area: 0.916
# Bootstrap #418 ROC area: 0.899
# Bootstrap #419 ROC area: 0.866
# Bootstrap #420 ROC area: 0.875
# Bootstrap #421 ROC area: 0.907
# Bootstrap #422 ROC area: 0.881
# Bootstrap #423 ROC area: 0.859
# Bootstrap #424 ROC area: 0.917
# Bootstrap #425 ROC area: 0.943
# Bootstrap #426 ROC area: 0.894
# Bootstrap #427 ROC area: 0.875
# Bootstrap #428 ROC area: 0.894
# Bootstrap #429 ROC area: 0.908
# Bootstrap #430 ROC area: 0.847
# Bootstrap #431 ROC area: 0.854
# Bootstrap #432 ROC area: 0.862
# Bootstrap #433 ROC area: 0.861
# Bootstrap #434 ROC area: 0.891
# Bootstrap #435 ROC area: 0.923
# Bootstrap #436 ROC area: 0.910
# Bootstrap #437 ROC area: 0.890
# Bootstrap #438 ROC area: 0.901
# Bootstrap #439 ROC area: 0.875
# Bootstrap #440 ROC area: 0.881
# Bootstrap #441 ROC area: 0.928
# Bootstrap #442 ROC area: 0.890
# Bootstrap #443 ROC area: 0.896
# Bootstrap #444 ROC area: 0.873
# Bootstrap #445 ROC area: 0.849
# Bootstrap #446 ROC area: 0.873
# Bootstrap #447 ROC area: 0.929
# Bootstrap #448 ROC area: 0.886
# Bootstrap #449 ROC area: 0.903
# Bootstrap #450 ROC area: 0.883
# Bootstrap #451 ROC area: 0.911
# Bootstrap #452 ROC area: 0.847
# Bootstrap #453 ROC area: 0.911
# Bootstrap #454 ROC area: 0.885
# Bootstrap #455 ROC area: 0.878
# Bootstrap #456 ROC area: 0.870
# Bootstrap #457 ROC area: 0.889
# Bootstrap #458 ROC area: 0.877
# Bootstrap #459 ROC area: 0.906
# Bootstrap #460 ROC area: 0.892
# Bootstrap #461 ROC area: 0.904
# Bootstrap #462 ROC area: 0.870
# Bootstrap #463 ROC area: 0.812
# Bootstrap #464 ROC area: 0.941
# Bootstrap #465 ROC area: 0.920
# Bootstrap #466 ROC area: 0.838
# Bootstrap #467 ROC area: 0.844
# Bootstrap #468 ROC area: 0.858
# Bootstrap #469 ROC area: 0.920
# Bootstrap #470 ROC area: 0.877
# Bootstrap #471 ROC area: 0.891
# Bootstrap #472 ROC area: 0.872
# Bootstrap #473 ROC area: 0.883
# Bootstrap #474 ROC area: 0.870
# Bootstrap #475 ROC area: 0.833
# Bootstrap #476 ROC area: 0.916
# Bootstrap #477 ROC area: 0.886
# Bootstrap #478 ROC area: 0.924
# Bootstrap #479 ROC area: 0.890
# Bootstrap #480 ROC area: 0.860
# Bootstrap #481 ROC area: 0.902
# Bootstrap #482 ROC area: 0.794
# Bootstrap #483 ROC area: 0.924
# Bootstrap #484 ROC area: 0.905
# Bootstrap #485 ROC area: 0.860
# Bootstrap #486 ROC area: 0.878
# Bootstrap #487 ROC area: 0.879
# Bootstrap #488 ROC area: 0.898
# Bootstrap #489 ROC area: 0.915
# Bootstrap #490 ROC area: 0.927
# Bootstrap #491 ROC area: 0.962
# Bootstrap #492 ROC area: 0.864
# Bootstrap #493 ROC area: 0.906
# Bootstrap #494 ROC area: 0.831
# Bootstrap #495 ROC area: 0.880
# Bootstrap #496 ROC area: 0.834
# Bootstrap #497 ROC area: 0.901
# Bootstrap #498 ROC area: 0.942
# Bootstrap #499 ROC area: 0.873
# Bootstrap #500 ROC area: 0.897
# Bootstrap #501 ROC area: 0.887
# Bootstrap #502 ROC area: 0.863
# Bootstrap #503 ROC area: 0.923
# Bootstrap #504 ROC area: 0.895
# Bootstrap #505 ROC area: 0.852
# Bootstrap #506 ROC area: 0.887
# Bootstrap #507 ROC area: 0.897
# Bootstrap #508 ROC area: 0.916
# Bootstrap #509 ROC area: 0.872
# Bootstrap #510 ROC area: 0.893
# Bootstrap #511 ROC area: 0.895
# Bootstrap #512 ROC area: 0.904
# Bootstrap #513 ROC area: 0.866
# Bootstrap #514 ROC area: 0.854
# Bootstrap #515 ROC area: 0.861
# Bootstrap #516 ROC area: 0.876
# Bootstrap #517 ROC area: 0.922
# Bootstrap #518 ROC area: 0.780
# Bootstrap #519 ROC area: 0.938
# Bootstrap #520 ROC area: 0.932
# Bootstrap #521 ROC area: 0.876
# Bootstrap #522 ROC area: 0.925
# Bootstrap #523 ROC area: 0.930
# Bootstrap #524 ROC area: 0.888
# Bootstrap #525 ROC area: 0.921
# Bootstrap #526 ROC area: 0.894
# Bootstrap #527 ROC area: 0.918
# Bootstrap #528 ROC area: 0.885
# Bootstrap #529 ROC area: 0.826
# Bootstrap #530 ROC area: 0.887
# Bootstrap #531 ROC area: 0.878
# Bootstrap #532 ROC area: 0.849
# Bootstrap #533 ROC area: 0.869
# Bootstrap #534 ROC area: 0.911
# Bootstrap #535 ROC area: 0.876
# Bootstrap #536 ROC area: 0.894
# Bootstrap #537 ROC area: 0.919
# Bootstrap #538 ROC area: 0.913
# Bootstrap #539 ROC area: 0.884
# Bootstrap #540 ROC area: 0.896
# Bootstrap #541 ROC area: 0.870
# Bootstrap #542 ROC area: 0.856
# Bootstrap #543 ROC area: 0.896
# Bootstrap #544 ROC area: 0.894
# Bootstrap #545 ROC area: 0.914
# Bootstrap #546 ROC area: 0.908
# Bootstrap #547 ROC area: 0.869
# Bootstrap #548 ROC area: 0.860
# Bootstrap #549 ROC area: 0.888
# Bootstrap #550 ROC area: 0.917
# Bootstrap #551 ROC area: 0.868
# Bootstrap #552 ROC area: 0.903
# Bootstrap #553 ROC area: 0.882
# Bootstrap #554 ROC area: 0.882
# Bootstrap #555 ROC area: 0.867
# Bootstrap #556 ROC area: 0.895
# Bootstrap #557 ROC area: 0.846
# Bootstrap #558 ROC area: 0.863
# Bootstrap #559 ROC area: 0.903
# Bootstrap #560 ROC area: 0.951
# Bootstrap #561 ROC area: 0.920
# Bootstrap #562 ROC area: 0.908
# Bootstrap #563 ROC area: 0.871
# Bootstrap #564 ROC area: 0.908
# Bootstrap #565 ROC area: 0.875
# Bootstrap #566 ROC area: 0.899
# Bootstrap #567 ROC area: 0.881
# Bootstrap #568 ROC area: 0.878
# Bootstrap #569 ROC area: 0.915
# Bootstrap #570 ROC area: 0.870
# Bootstrap #571 ROC area: 0.905
# Bootstrap #572 ROC area: 0.850
# Bootstrap #573 ROC area: 0.901
# Bootstrap #574 ROC area: 0.940
# Bootstrap #575 ROC area: 0.896
# Bootstrap #576 ROC area: 0.917
# Bootstrap #577 ROC area: 0.881
# Bootstrap #578 ROC area: 0.848
# Bootstrap #579 ROC area: 0.910
# Bootstrap #580 ROC area: 0.868
# Bootstrap #581 ROC area: 0.900
# Bootstrap #582 ROC area: 0.886
# Bootstrap #583 ROC area: 0.909
# Bootstrap #584 ROC area: 0.854
# Bootstrap #585 ROC area: 0.897
# Bootstrap #586 ROC area: 0.852
# Bootstrap #587 ROC area: 0.931
# Bootstrap #588 ROC area: 0.848
# Bootstrap #589 ROC area: 0.854
# Bootstrap #590 ROC area: 0.889
# Bootstrap #591 ROC area: 0.881
# Bootstrap #592 ROC area: 0.886
# Bootstrap #593 ROC area: 0.872
# Bootstrap #594 ROC area: 0.850
# Bootstrap #595 ROC area: 0.890
# Bootstrap #596 ROC area: 0.900
# Bootstrap #597 ROC area: 0.894
# Bootstrap #598 ROC area: 0.893
# Bootstrap #599 ROC area: 0.873
# Bootstrap #600 ROC area: 0.931
# Bootstrap #601 ROC area: 0.876
# Bootstrap #602 ROC area: 0.882
# Bootstrap #603 ROC area: 0.904
# Bootstrap #604 ROC area: 0.880
# Bootstrap #605 ROC area: 0.895
# Bootstrap #606 ROC area: 0.898
# Bootstrap #607 ROC area: 0.867
# Bootstrap #608 ROC area: 0.887
# Bootstrap #609 ROC area: 0.924
# Bootstrap #610 ROC area: 0.881
# Bootstrap #611 ROC area: 0.910
# Bootstrap #612 ROC area: 0.819
# Bootstrap #613 ROC area: 0.842
# Bootstrap #614 ROC area: 0.898
# Bootstrap #615 ROC area: 0.903
# Bootstrap #616 ROC area: 0.890
# Bootstrap #617 ROC area: 0.858
# Bootstrap #618 ROC area: 0.870
# Bootstrap #619 ROC area: 0.892
# Bootstrap #620 ROC area: 0.878
# Bootstrap #621 ROC area: 0.906
# Bootstrap #622 ROC area: 0.885
# Bootstrap #623 ROC area: 0.888
# Bootstrap #624 ROC area: 0.922
# Bootstrap #625 ROC area: 0.866
# Bootstrap #626 ROC area: 0.890
# Bootstrap #627 ROC area: 0.937
# Bootstrap #628 ROC area: 0.854
# Bootstrap #629 ROC area: 0.908
# Bootstrap #630 ROC area: 0.874
# Bootstrap #631 ROC area: 0.889
# Bootstrap #632 ROC area: 0.801
# Bootstrap #633 ROC area: 0.862
# Bootstrap #634 ROC area: 0.841
# Bootstrap #635 ROC area: 0.895
# Bootstrap #636 ROC area: 0.860
# Bootstrap #637 ROC area: 0.925
# Bootstrap #638 ROC area: 0.914
# Bootstrap #639 ROC area: 0.891
# Bootstrap #640 ROC area: 0.817
# Bootstrap #641 ROC area: 0.901
# Bootstrap #642 ROC area: 0.904
# Bootstrap #643 ROC area: 0.848
# Bootstrap #644 ROC area: 0.925
# Bootstrap #645 ROC area: 0.867
# Bootstrap #646 ROC area: 0.887
# Bootstrap #647 ROC area: 0.932
# Bootstrap #648 ROC area: 0.853
# Bootstrap #649 ROC area: 0.913
# Bootstrap #650 ROC area: 0.868
# Bootstrap #651 ROC area: 0.924
# Bootstrap #652 ROC area: 0.903
# Bootstrap #653 ROC area: 0.899
# Bootstrap #654 ROC area: 0.852
# Bootstrap #655 ROC area: 0.867
# Bootstrap #656 ROC area: 0.905
# Bootstrap #657 ROC area: 0.900
# Bootstrap #658 ROC area: 0.863
# Bootstrap #659 ROC area: 0.898
# Bootstrap #660 ROC area: 0.894
# Bootstrap #661 ROC area: 0.884
# Bootstrap #662 ROC area: 0.898
# Bootstrap #663 ROC area: 0.849
# Bootstrap #664 ROC area: 0.914
# Bootstrap #665 ROC area: 0.904
# Bootstrap #666 ROC area: 0.899
# Bootstrap #667 ROC area: 0.907
# Bootstrap #668 ROC area: 0.920
# Bootstrap #669 ROC area: 0.903
# Bootstrap #670 ROC area: 0.924
# Bootstrap #671 ROC area: 0.887
# Bootstrap #672 ROC area: 0.883
# Bootstrap #673 ROC area: 0.916
# Bootstrap #674 ROC area: 0.906
# Bootstrap #675 ROC area: 0.871
# Bootstrap #676 ROC area: 0.919
# Bootstrap #677 ROC area: 0.882
# Bootstrap #678 ROC area: 0.873
# Bootstrap #679 ROC area: 0.927
# Bootstrap #680 ROC area: 0.871
# Bootstrap #681 ROC area: 0.914
# Bootstrap #682 ROC area: 0.882
# Bootstrap #683 ROC area: 0.885
# Bootstrap #684 ROC area: 0.868
# Bootstrap #685 ROC area: 0.892
# Bootstrap #686 ROC area: 0.933
# Bootstrap #687 ROC area: 0.871
# Bootstrap #688 ROC area: 0.846
# Bootstrap #689 ROC area: 0.876
# Bootstrap #690 ROC area: 0.876
# Bootstrap #691 ROC area: 0.885
# Bootstrap #692 ROC area: 0.886
# Bootstrap #693 ROC area: 0.869
# Bootstrap #694 ROC area: 0.900
# Bootstrap #695 ROC area: 0.888
# Bootstrap #696 ROC area: 0.927
# Bootstrap #697 ROC area: 0.898
# Bootstrap #698 ROC area: 0.902
# Bootstrap #699 ROC area: 0.904
# Bootstrap #700 ROC area: 0.925
# Bootstrap #701 ROC area: 0.883
# Bootstrap #702 ROC area: 0.901
# Bootstrap #703 ROC area: 0.920
# Bootstrap #704 ROC area: 0.899
# Bootstrap #705 ROC area: 0.924
# Bootstrap #706 ROC area: 0.942
# Bootstrap #707 ROC area: 0.837
# Bootstrap #708 ROC area: 0.888
# Bootstrap #709 ROC area: 0.944
# Bootstrap #710 ROC area: 0.890
# Bootstrap #711 ROC area: 0.887
# Bootstrap #712 ROC area: 0.864
# Bootstrap #713 ROC area: 0.921
# Bootstrap #714 ROC area: 0.911
# Bootstrap #715 ROC area: 0.837
# Bootstrap #716 ROC area: 0.879
# Bootstrap #717 ROC area: 0.888
# Bootstrap #718 ROC area: 0.888
# Bootstrap #719 ROC area: 0.880
# Bootstrap #720 ROC area: 0.885
# Bootstrap #721 ROC area: 0.851
# Bootstrap #722 ROC area: 0.916
# Bootstrap #723 ROC area: 0.888
# Bootstrap #724 ROC area: 0.885
# Bootstrap #725 ROC area: 0.894
# Bootstrap #726 ROC area: 0.882
# Bootstrap #727 ROC area: 0.891
# Bootstrap #728 ROC area: 0.932
# Bootstrap #729 ROC area: 0.850
# Bootstrap #730 ROC area: 0.893
# Bootstrap #731 ROC area: 0.888
# Bootstrap #732 ROC area: 0.862
# Bootstrap #733 ROC area: 0.864
# Bootstrap #734 ROC area: 0.929
# Bootstrap #735 ROC area: 0.866
# Bootstrap #736 ROC area: 0.886
# Bootstrap #737 ROC area: 0.844
# Bootstrap #738 ROC area: 0.919
# Bootstrap #739 ROC area: 0.904
# Bootstrap #740 ROC area: 0.907
# Bootstrap #741 ROC area: 0.899
# Bootstrap #742 ROC area: 0.882
# Bootstrap #743 ROC area: 0.887
# Bootstrap #744 ROC area: 0.847
# Bootstrap #745 ROC area: 0.910
# Bootstrap #746 ROC area: 0.874
# Bootstrap #747 ROC area: 0.908
# Bootstrap #748 ROC area: 0.904
# Bootstrap #749 ROC area: 0.887
# Bootstrap #750 ROC area: 0.913
# Bootstrap #751 ROC area: 0.883
# Bootstrap #752 ROC area: 0.884
# Bootstrap #753 ROC area: 0.916
# Bootstrap #754 ROC area: 0.910
# Bootstrap #755 ROC area: 0.898
# Bootstrap #756 ROC area: 0.919
# Bootstrap #757 ROC area: 0.873
# Bootstrap #758 ROC area: 0.926
# Bootstrap #759 ROC area: 0.878
# Bootstrap #760 ROC area: 0.908
# Bootstrap #761 ROC area: 0.878
# Bootstrap #762 ROC area: 0.907
# Bootstrap #763 ROC area: 0.914
# Bootstrap #764 ROC area: 0.856
# Bootstrap #765 ROC area: 0.861
# Bootstrap #766 ROC area: 0.917
# Bootstrap #767 ROC area: 0.906
# Bootstrap #768 ROC area: 0.863
# Bootstrap #769 ROC area: 0.877
# Bootstrap #770 ROC area: 0.890
# Bootstrap #771 ROC area: 0.939
# Bootstrap #772 ROC area: 0.847
# Bootstrap #773 ROC area: 0.852
# Bootstrap #774 ROC area: 0.889
# Bootstrap #775 ROC area: 0.900
# Bootstrap #776 ROC area: 0.881
# Bootstrap #777 ROC area: 0.888
# Bootstrap #778 ROC area: 0.910
# Bootstrap #779 ROC area: 0.913
# Bootstrap #780 ROC area: 0.868
# Bootstrap #781 ROC area: 0.893
# Bootstrap #782 ROC area: 0.902
# Bootstrap #783 ROC area: 0.908
# Bootstrap #784 ROC area: 0.895
# Bootstrap #785 ROC area: 0.881
# Bootstrap #786 ROC area: 0.907
# Bootstrap #787 ROC area: 0.914
# Bootstrap #788 ROC area: 0.887
# Bootstrap #789 ROC area: 0.868
# Bootstrap #790 ROC area: 0.916
# Bootstrap #791 ROC area: 0.896
# Bootstrap #792 ROC area: 0.832
# Bootstrap #793 ROC area: 0.893
# Bootstrap #794 ROC area: 0.856
# Bootstrap #795 ROC area: 0.916
# Bootstrap #796 ROC area: 0.818
# Bootstrap #797 ROC area: 0.880
# Bootstrap #798 ROC area: 0.887
# Bootstrap #799 ROC area: 0.861
# Bootstrap #800 ROC area: 0.877
# Bootstrap #801 ROC area: 0.881
# Bootstrap #802 ROC area: 0.891
# Bootstrap #803 ROC area: 0.874
# Bootstrap #804 ROC area: 0.858
# Bootstrap #805 ROC area: 0.876
# Bootstrap #806 ROC area: 0.881
# Bootstrap #807 ROC area: 0.909
# Bootstrap #808 ROC area: 0.894
# Bootstrap #809 ROC area: 0.909
# Bootstrap #810 ROC area: 0.836
# Bootstrap #811 ROC area: 0.902
# Bootstrap #812 ROC area: 0.904
# Bootstrap #813 ROC area: 0.892
# Bootstrap #814 ROC area: 0.848
# Bootstrap #815 ROC area: 0.952
# Bootstrap #816 ROC area: 0.891
# Bootstrap #817 ROC area: 0.918
# Bootstrap #818 ROC area: 0.934
# Bootstrap #819 ROC area: 0.901
# Bootstrap #820 ROC area: 0.869
# Bootstrap #821 ROC area: 0.884
# Bootstrap #822 ROC area: 0.905
# Bootstrap #823 ROC area: 0.890
# Bootstrap #824 ROC area: 0.897
# Bootstrap #825 ROC area: 0.888
# Bootstrap #826 ROC area: 0.902
# Bootstrap #827 ROC area: 0.917
# Bootstrap #828 ROC area: 0.858
# Bootstrap #829 ROC area: 0.870
# Bootstrap #830 ROC area: 0.900
# Bootstrap #831 ROC area: 0.868
# Bootstrap #832 ROC area: 0.927
# Bootstrap #833 ROC area: 0.856
# Bootstrap #834 ROC area: 0.844
# Bootstrap #835 ROC area: 0.889
# Bootstrap #836 ROC area: 0.916
# Bootstrap #837 ROC area: 0.895
# Bootstrap #838 ROC area: 0.889
# Bootstrap #839 ROC area: 0.893
# Bootstrap #840 ROC area: 0.888
# Bootstrap #841 ROC area: 0.865
# Bootstrap #842 ROC area: 0.875
# Bootstrap #843 ROC area: 0.796
# Bootstrap #844 ROC area: 0.908
# Bootstrap #845 ROC area: 0.930
# Bootstrap #846 ROC area: 0.902
# Bootstrap #847 ROC area: 0.892
# Bootstrap #848 ROC area: 0.855
# Bootstrap #849 ROC area: 0.944
# Bootstrap #850 ROC area: 0.911
# Bootstrap #851 ROC area: 0.885
# Bootstrap #852 ROC area: 0.883
# Bootstrap #853 ROC area: 0.889
# Bootstrap #854 ROC area: 0.913
# Bootstrap #855 ROC area: 0.888
# Bootstrap #856 ROC area: 0.879
# Bootstrap #857 ROC area: 0.882
# Bootstrap #858 ROC area: 0.854
# Bootstrap #859 ROC area: 0.888
# Bootstrap #860 ROC area: 0.880
# Bootstrap #861 ROC area: 0.854
# Bootstrap #862 ROC area: 0.948
# Bootstrap #863 ROC area: 0.871
# Bootstrap #864 ROC area: 0.904
# Bootstrap #865 ROC area: 0.928
# Bootstrap #866 ROC area: 0.886
# Bootstrap #867 ROC area: 0.924
# Bootstrap #868 ROC area: 0.869
# Bootstrap #869 ROC area: 0.817
# Bootstrap #870 ROC area: 0.882
# Bootstrap #871 ROC area: 0.856
# Bootstrap #872 ROC area: 0.853
# Bootstrap #873 ROC area: 0.904
# Bootstrap #874 ROC area: 0.884
# Bootstrap #875 ROC area: 0.945
# Bootstrap #876 ROC area: 0.849
# Bootstrap #877 ROC area: 0.863
# Bootstrap #878 ROC area: 0.906
# Bootstrap #879 ROC area: 0.908
# Bootstrap #880 ROC area: 0.930
# Bootstrap #881 ROC area: 0.888
# Bootstrap #882 ROC area: 0.886
# Bootstrap #883 ROC area: 0.911
# Bootstrap #884 ROC area: 0.923
# Bootstrap #885 ROC area: 0.918
# Bootstrap #886 ROC area: 0.894
# Bootstrap #887 ROC area: 0.947
# Bootstrap #888 ROC area: 0.860
# Bootstrap #889 ROC area: 0.895
# Bootstrap #890 ROC area: 0.932
# Bootstrap #891 ROC area: 0.876
# Bootstrap #892 ROC area: 0.897
# Bootstrap #893 ROC area: 0.876
# Bootstrap #894 ROC area: 0.942
# Bootstrap #895 ROC area: 0.921
# Bootstrap #896 ROC area: 0.916
# Bootstrap #897 ROC area: 0.876
# Bootstrap #898 ROC area: 0.884
# Bootstrap #899 ROC area: 0.873
# Bootstrap #900 ROC area: 0.870
# Bootstrap #901 ROC area: 0.899
# Bootstrap #902 ROC area: 0.861
# Bootstrap #903 ROC area: 0.920
# Bootstrap #904 ROC area: 0.851
# Bootstrap #905 ROC area: 0.845
# Bootstrap #906 ROC area: 0.920
# Bootstrap #907 ROC area: 0.860
# Bootstrap #908 ROC area: 0.850
# Bootstrap #909 ROC area: 0.948
# Bootstrap #910 ROC area: 0.905
# Bootstrap #911 ROC area: 0.930
# Bootstrap #912 ROC area: 0.897
# Bootstrap #913 ROC area: 0.913
# Bootstrap #914 ROC area: 0.904
# Bootstrap #915 ROC area: 0.913
# Bootstrap #916 ROC area: 0.938
# Bootstrap #917 ROC area: 0.915
# Bootstrap #918 ROC area: 0.892
# Bootstrap #919 ROC area: 0.896
# Bootstrap #920 ROC area: 0.910
# Bootstrap #921 ROC area: 0.848
# Bootstrap #922 ROC area: 0.872
# Bootstrap #923 ROC area: 0.854
# Bootstrap #924 ROC area: 0.899
# Bootstrap #925 ROC area: 0.908
# Bootstrap #926 ROC area: 0.844
# Bootstrap #927 ROC area: 0.924
# Bootstrap #928 ROC area: 0.862
# Bootstrap #929 ROC area: 0.874
# Bootstrap #930 ROC area: 0.938
# Bootstrap #931 ROC area: 0.900
# Bootstrap #932 ROC area: 0.919
# Bootstrap #933 ROC area: 0.918
# Bootstrap #934 ROC area: 0.892
# Bootstrap #935 ROC area: 0.901
# Bootstrap #936 ROC area: 0.887
# Bootstrap #937 ROC area: 0.879
# Bootstrap #938 ROC area: 0.924
# Bootstrap #939 ROC area: 0.888
# Bootstrap #940 ROC area: 0.912
# Bootstrap #941 ROC area: 0.874
# Bootstrap #942 ROC area: 0.898
# Bootstrap #943 ROC area: 0.899
# Bootstrap #944 ROC area: 0.915
# Bootstrap #945 ROC area: 0.898
# Bootstrap #946 ROC area: 0.872
# Bootstrap #947 ROC area: 0.890
# Bootstrap #948 ROC area: 0.890
# Bootstrap #949 ROC area: 0.833
# Bootstrap #950 ROC area: 0.889
# Bootstrap #951 ROC area: 0.895
# Bootstrap #952 ROC area: 0.913
# Bootstrap #953 ROC area: 0.898
# Bootstrap #954 ROC area: 0.873
# Bootstrap #955 ROC area: 0.891
# Bootstrap #956 ROC area: 0.865
# Bootstrap #957 ROC area: 0.870
# Bootstrap #958 ROC area: 0.887
# Bootstrap #959 ROC area: 0.855
# Bootstrap #960 ROC area: 0.919
# Bootstrap #961 ROC area: 0.877
# Bootstrap #962 ROC area: 0.881
# Bootstrap #963 ROC area: 0.906
# Bootstrap #964 ROC area: 0.884
# Bootstrap #965 ROC area: 0.899
# Bootstrap #966 ROC area: 0.899
# Bootstrap #967 ROC area: 0.930
# Bootstrap #968 ROC area: 0.921
# Bootstrap #969 ROC area: 0.846
# Bootstrap #970 ROC area: 0.871
# Bootstrap #971 ROC area: 0.903
# Bootstrap #972 ROC area: 0.873
# Bootstrap #973 ROC area: 0.901
# Bootstrap #974 ROC area: 0.901
# Bootstrap #975 ROC area: 0.906
# Bootstrap #976 ROC area: 0.865
# Bootstrap #977 ROC area: 0.890
# Bootstrap #978 ROC area: 0.918
# Bootstrap #979 ROC area: 0.912
# Bootstrap #980 ROC area: 0.879
# Bootstrap #981 ROC area: 0.881
# Bootstrap #982 ROC area: 0.904
# Bootstrap #983 ROC area: 0.936
# Bootstrap #984 ROC area: 0.925
# Bootstrap #985 ROC area: 0.881
# Bootstrap #986 ROC area: 0.883
# Bootstrap #987 ROC area: 0.870
# Bootstrap #988 ROC area: 0.917
# Bootstrap #989 ROC area: 0.888
# Bootstrap #990 ROC area: 0.901
# Bootstrap #991 ROC area: 0.817
# Bootstrap #992 ROC area: 0.888
# Bootstrap #993 ROC area: 0.901
# Bootstrap #994 ROC area: 0.889
# Bootstrap #995 ROC area: 0.931
# Bootstrap #996 ROC area: 0.915
# Bootstrap #997 ROC area: 0.871
# Bootstrap #998 ROC area: 0.877
# Bootstrap #999 ROC area: 0.895
# Bootstrap #1000 ROC area: 0.838
# Confidence interval for the score: [0.844 - 0.931]
